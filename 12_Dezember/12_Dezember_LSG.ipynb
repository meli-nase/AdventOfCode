# %% [markdown]
# ## Erdbebendaten visualisieren
#
# ### 0. Python vorbereiten
# Importiere die Libraries `numpy` und  `matplotlib.pyplot`.

# %% [markdown]
# ### **Der schweizerische Erdbebenkatalog für 2014**
#
# > <font color=#cc257b>Ein **Erdbebenkatalog** enthält alle Beben, die von einem seismologischen Dienst erfasst und lokalisiert wurden.</font>
#
# In der heutigen Aufgabe arbeiten wir mit einem **Ausschnitt des schweizerischen Erdbebenkatalogs**, der vom [Schweizerischen Erdbebendienst (SED)](http://seismo.ethz.ch/de/home/) erstellt wird. Wegen der [Verteilung der Seismometer](http://static.seismo.ethz.ch/eq_maps/2019_Cont_RT_Stations_Monitored_by_SED_InAndAround_CH_no_names_EN.pdf) können Erdbeben in der Schweiz sowie im grenznahen Ausland erfasst werden.
#
# Die Datei `CH_seiscat_2014.csv` in diesem Ordner enthält Informationen über Beben **im Jahr 2014**.
#
# Die Daten sind in vier Spalten angeordnet:
# | LON [°E]  | LAT [°N] | TIEFE [KM] | MAGNITUDE |
# |---|---|---|---|
#
# **Die Datei enthält also für jedes Erdbeben im Jahr 2014 vier Kenngrössen:**
#
# - geographische Koordinaten, also **_Longitude_** (Längengrad) und **_Latitude_** (Breitengrad)
# - die **_Tiefe_** des Erdbebenherds in Kilometer
# - die [__*Magnitude*__](http://seismo.ethz.ch/de/knowledge/things-to-know/faq/#cc_00124.xml) des Bebens, ein Mass für die freigesetzte Energie
#
# ---
#
# In der untenstehenden Code-Zelle wird die Datei in ein NumPy-Array namens `daten` geladen.

# %%
# Daten Erdbeben und Koordinaten Schweiz einlesen 

daten = np.loadtxt('CH_seiscat_2014.csv', skiprows=1, delimiter=',')
grenze = np.loadtxt('CH_grenze.csv', delimiter=',', skiprows=1)

# %% [markdown]
# **In dieser Aufgabe sollst du die Erdbeben von 2014 in _zwei Karten_ visualisieren:**
#
# - **Abbildung 1** zeigt die geographische Verteilung der Beben, wobei die __Grösse und Farbe__ der Symbole die _**Tiefe**_ des Erdbebens darstellt.
# - **Abbildung 2** zeigt die geographische Verteilung der Beben, wobei die __Grösse und Farbe__ der Symbole die _**Magnitude**_ des Erdbebens darstellt.
#
# **Beide Karten sollen die **Schweizer Grenze** im Hintergrund zeigen.**

# %% [markdown]
# #### **MÖGLICHE VORGEHENSWEISE**
#
# 1. Als Erstes musst du die Datei mit den **Koordinaten der Schweizer Grenze** einlesen.
#
# 2. Dann kannst du **jede Spalte von `daten` als einzelne Variable speichern**, z.B. die erste Spalte (mit Index `0`!) in eine Variable namens `longitude`. Dasselbe mit den Koordinaten der Schweizer Grenze.
#
# 3. In einem letzten Schritt kannst du die **Skalierungsvariablen** definieren, damit du in deinen Karten die Grösse der Symbole steuern kannst.
#
# Tipp
# Die Richter-Skala für Erdbebenmagnituden ist _logarithmisch_ &mdash; das bedeutet, eine Zunahme um eine Einheit entspricht einer Verzehnfachung: Magnitude 3, $10^3$, ist zehnmal grösser als Magnitude 2, $10^2$.

# %%
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/collections.py:999: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# /var/folders/5g/q633z24d7dx6gy2_3n2vv1h40000gn/T/ipykernel_60570/172042545.py:19: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# <font size = 3> **Die obige Abbildung zeigt das Jahr 2014 bezüglich Erdbebendaten. Die Punkte zeigen den Ort und die Tiefe (s. Skala rechts) der gemessenen Erdbeben.** </font>

# %%
# Out:
# /var/folders/5g/q633z24d7dx6gy2_3n2vv1h40000gn/T/ipykernel_60570/234280316.py:22: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# <font size = 3> **Die obige Abbildung zeigt das Jahr 2014 bezüglich Erdbebendaten. Die Punkte zeigen den Ort und die Stärke (s. Skala rechts) der gemessenen Erdbeben.** </font>
